# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import cv2
from collections import OrderedDict
from PIL import Image

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms, models
from torchvision.models import resnet18, ResNet18_Weights
# Out:
# C:\Users\chloe\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
data_dir = 'data'
dataset = datasets.ImageFolder(root=data_dir, transform=transform)
total_size = len(dataset)

# %%
total_size
# Out:
# 609

# %%
train_size = int(total_size * 0.7)
val_size = int(total_size * 0.2)
test_size = total_size - train_size - val_size

# %%
train_size
# Out:
# 426

# %%
val_size
# Out:
# 121

# %%
test_size
# Out:
# 62

# %%
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
data_iterator = iter(train_loader)
batch = next(data_iterator)
images, labels = batch

# %%
print("Shape of the images in the batch:", images.shape)  # Prints the shape of the batch of images
print("Labels in the batch:", labels)  # Prints the labels in the batch
# Out:
# Shape of the images in the batch: torch.Size([32, 3, 256, 256])
# Labels in the batch: tensor([2, 2, 2, 3, 1, 0, 5, 2, 3, 5, 2, 5, 1, 2, 4, 0, 3, 6, 6, 3, 4, 2, 6, 1,
#         5, 2, 1, 4, 2, 6, 0, 1])

# %%
def imshow(img, label):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title(f"{label}")
    plt.show()

# %%
imshow(images[0], labels[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def show_transformed_images(images, labels):
    grid = torchvision.utils.make_grid(images, nrow=3)
    plt.figure(figsize=(20,20))
    plt.imshow(np.transpose(grid, (1,2,0)))
    print('labels: ',labels)

# %%
show_transformed_images(images, labels)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# labels:  tensor([2, 2, 2, 3, 1, 0, 5, 2, 3, 5, 2, 5, 1, 2, 4, 0, 3, 6, 6, 3, 4, 2, 6, 1,
#         5, 2, 1, 4, 2, 6, 0, 1])

# %%
def set_device():
    if torch.cuda.is_available():
        dev = "cuda:0"
    else:
        dev="cpu"
    return torch.device(dev)

# %%
device = set_device()

# %%
model = models.resnet18(pretrained=True)
model
# Out:
# C:\Users\chloe\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\chloe\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
# ...

# %%
num_classes = 8
model.fc = nn.Linear(model.fc.in_features, num_classes)

# %%
for name, param in model.named_parameters():
    if "fc" in name:  # Unfreeze the final classification layer
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 20

for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    
    # Validation phase
    model.eval()  # Set model to evaluate mode
    running_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item() * images.size(0)
            
            # Calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss = running_val_loss / len(val_loader.dataset)
    val_accuracy = correct / total

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_loss:.3f}, Validation Loss: {val_loss:.3f}, Accuracy: {val_accuracy:.2f}')
# Out:
# Epoch [1/20], Train Loss: 2.021, Validation Loss: 1.791, Accuracy: 0.34
# Epoch [2/20], Train Loss: 1.551, Validation Loss: 1.444, Accuracy: 0.58
# Epoch [3/20], Train Loss: 1.257, Validation Loss: 1.270, Accuracy: 0.58
# Epoch [4/20], Train Loss: 1.080, Validation Loss: 1.173, Accuracy: 0.65
# Epoch [5/20], Train Loss: 0.958, Validation Loss: 1.089, Accuracy: 0.64
# Epoch [6/20], Train Loss: 0.858, Validation Loss: 1.068, Accuracy: 0.65
# Epoch [7/20], Train Loss: 0.796, Validation Loss: 0.994, Accuracy: 0.64
# Epoch [8/20], Train Loss: 0.730, Validation Loss: 0.974, Accuracy: 0.65
# Epoch [9/20], Train Loss: 0.690, Validation Loss: 0.948, Accuracy: 0.65
# Epoch [10/20], Train Loss: 0.650, Validation Loss: 0.923, Accuracy: 0.67
# Epoch [11/20], Train Loss: 0.605, Validation Loss: 0.918, Accuracy: 0.67
# Epoch [12/20], Train Loss: 0.594, Validation Loss: 0.893, Accuracy: 0.66
# Epoch [13/20], Train Loss: 0.586, Validation Loss: 0.891, Accuracy: 0.67
# ...

# %%
# Test model
model.eval()
model.to(device)

with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        
        _, predicted = torch.max(outputs.data, 1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
accuracy = 100 * correct / total
print(f'Accuracy of the model on the test set: {accuracy:.2f}%')
# Out:
# Accuracy of the model on the test set: 77.42%

# %%
torch.save(model.state_dict(), 'skin_disease_model.pth')

# %%
# Load the saved model
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 8)
model.load_state_dict(torch.load('skin_disease_model.pth'))
model.eval()

# Create a new model with the correct final layer
new_model = models.resnet18(pretrained=True)
new_model.fc = nn.Linear(new_model.fc.in_features, 8)

# %%
image_path = 'melanoma.jpg'
image = Image.open(image_path)
input_tensor = transform(image).unsqueeze(0)

new_model.eval()
with torch.no_grad():
    output = new_model(input_tensor)
    print(output)
    
probabilities = torch.nn.functional.softmax(output, dim=1)  # Convert logits to probabilities
top_prob, top_cls = probabilities.topk(3, dim=1)  # Get the top 3 elements

class_names = ['actinic keratosis',
               'atopic dermatisis',
               'benign keratosis',
               'dermatofibroma',
               'melanocytic nevus',
               'melanoma',
               'squamous cell cercinoma',
               'tinea ringworm candidiasis']
# _, predicted_class = output.max(1)
# predicted_class_name = class_names[predicted_class.item()]
# print("Predicted class index:", predicted_class.item(), "Predicted class name:", predicted_class_name)

for i in range(top_prob.size(1)):
    print(f"{class_names[top_cls[0][i]]}: {top_prob[0][i].item()*100:.2f}%")

# Display the image with the predicted class name
plt.imshow(image)
plt.axis('off')
#plt.text(10, 10, f'Predicted: {predicted_class_name}', fontsize=12, color='white', backgroundcolor='red')
plt.text(10, 10, f'Top Prediction: {class_names[top_cls[0][0]]}', fontsize=12, color='white', backgroundcolor='red')
plt.show()
# Out:
# tensor([[ 0.2948, -0.0552,  0.2762,  0.0995,  0.2006,  0.3594,  0.8365, -0.7029]])
# squamous cell cercinoma: 22.70%
# melanoma: 14.09%
# actinic keratosis: 13.20%
